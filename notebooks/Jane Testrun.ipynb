# %%
# %matplotlib inline
import pyart
import matplotlib.pyplot as plt
import numpy as np

# %%
dset = pyart.io.read('C:/Users/jpan/Documents/data/KVNX20110520_100147_V06.gz')

# %%
type(dset)
# Out:
# pyart.core.radar.Radar

# %%
dset.fields.keys()
# Out:
# ['differential_phase',
#  'cross_correlation_ratio',
#  'spectrum_width',
#  'reflectivity',
#  'differential_reflectivity',
#  'velocity']

# %%
type(dset.fields['reflectivity'])
# Out:
# dict

# %%
display = pyart.graph.RadarDisplay(dset)

# %%
display.plot_ppi?

# %%
display.plot_ppi('velocity', 1, vmin=-20, vmax=20)
#vmin/vmax refers to luminance, i.e. photometric measure of luminous intensity
#per unit area of light traveling in a given direction.)
display.set_limits(xlim=(-150, 100), ylim=(-125, 100), ax=None)

# %%
ax = fig.add_subplot(111)
display.plot('reflectivity', 0)
display.plot_range_ring(dset.range['data'][-1]/1000., ax=ax)
display.set_limits(xlim=(-210, 250), ylim=(-400, 330), ax=None)
plt.show()

# %%
plt.figure(figsize = (20, 10))
plt.imshow(dset.fields['reflectivity']['data'], aspect = 0.1, origin = 'bottom')
plt.xlabel('range gate')
plt.ylabel('ray number')
