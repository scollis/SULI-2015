# %%
print "Hello World"
# Out:
# Hello World

# %%
# %matplotlib inline
import pyart
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /Users/jpan/anaconda/lib/python2.7/site-packages/pyart/graph/__init__.py:32: UserWarning: No grid plotting support, requires basemap.
#   warnings.warn('No grid plotting support, requires basemap.')
# /Users/jpan/anaconda/lib/python2.7/site-packages/pyart/graph/__init__.py:38: UserWarning: No grid plotting support, requires basemap.
#   warnings.warn('No grid plotting support, requires basemap.')

# %%
dset = pyart.io.read('../data/KVNX20110520_111530_V06.gz')

# %%
type(dset)
# Out:
# pyart.core.radar.Radar

# %%
dset.fields.keys()
# Out:
# ['differential_phase',
#  'cross_correlation_ratio',
#  'spectrum_width',
#  'reflectivity',
#  'differential_reflectivity',
#  'velocity']

# %%
type(dset.fields['reflectivity'])
# Out:
# dict

# %%
plt.figure(figsize = (20, 10))
plt.imshow(dset.fields['reflectivity']['data'], aspect = 0.1, origin = 'bottom')
plt.xlabel('range gate')
plt.ylabel('ray number')

# %%
print "Bye Forever World"
# Out:
# Bye Forever World
